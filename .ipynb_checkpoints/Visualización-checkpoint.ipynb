# %%
tabla = pd.read_csv('data/tabla.csv')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tabla
# Out:
#    CHAMPION    WIN  DERR/VIC
# 0    Ezreal  False     18117
# 1    Ezreal   True     17731
# 2    LeeSin  False     14990
# 3    LeeSin   True     15557
# 4     Kaisa  False     14415
# 5     Kaisa   True     13810
# 6    Thresh  False     12888
# 7    Thresh   True     13449
# 8     Viego  False     11621
# 9     Viego   True     11203
# 10     Lulu  False     10671
# 11     Lulu   True     10982
# 12     Sett  False     10047
# 13     Sett   True      9928
# 14    Karma  False     10242
# 15    Karma   True      9672
# 16    Sylas  False      9817
# 17    Sylas   True      9896
# 18    Diana  False      9535
# 19    Diana   True      8826

# %%
tabla.value_counts().plot(kind="bar", figsize=(12,6), title="Proporción Victorias-Derrotas")
barplot = sns.barplot(x="CHAMPION", y="DERR/VIC", data=tabla, ci="sd");
